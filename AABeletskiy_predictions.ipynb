# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

pd.options.display.max_columns = 100
# %matplotlib inline

# %%
data = pd.read_csv(r'C:\Users\Public\Kurs_project_task\train.csv')

data.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35    2.0  47.981561   29.442751            6.0      7
# 1  15053          41    3.0  65.683640   40.049543            8.0      7
# 2   4765          53    2.0  44.947953   29.197612            0.0      8
# 3   5809          58    2.0  53.352981   52.731512            9.0      8
# 4  10783          99    1.0  39.649192   23.776169            7.0     11
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0         9.0       1969   0.089040         B         B        33      7976
# 1         9.0       1978   0.000070         B         B        46     10309
# 2        12.0       1968   0.049637         B         B        34      7759
# 3        17.0       1977   0.437885         B         B        23      5735
# 4        12.0       1976   0.012339         B         B        35      5776
#
# ...

# %%
data.head(15)
# Out:
#        Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0   14038          35    2.0  47.981561   29.442751            6.0      7
# 1   15053          41    3.0  65.683640   40.049543            8.0      7
# 2    4765          53    2.0  44.947953   29.197612            0.0      8
# 3    5809          58    2.0  53.352981   52.731512            9.0      8
# 4   10783          99    1.0  39.649192   23.776169            7.0     11
# 5   12915          59    3.0  80.384479   46.683720           12.0      5
# 6   14549         154    2.0  62.254114   37.160377            7.0      3
# 7   11993          74    2.0  80.312926   68.265987            0.0     14
# 8    5172           1    2.0  64.511437   54.834722            1.0      9
# 9    8649          23    1.0  46.461409   18.915552            8.0     13
# 10  15370          28    2.0  46.304907   27.922584            6.0      8
# 11  12427          31    3.0  68.808859   45.736906            7.0      1
# ...

# %%
train, valid = train_test_split(data, test_size=0.3, random_state=42)

train.head()
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 9069  14604          23    1.0   41.681380   22.796166            8.0     14
# 2603   5621          23    3.0  163.495333  161.504222           12.0      5
# 7738    235          87    1.0   39.710131   19.538663            8.0      4
# 1579  16258          48    3.0   96.056784   98.152802            1.0     15
# 5058  10773          77    3.0   79.195825   44.421062           10.0     16
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 9069        17.0       2015   0.075779         B         B         6
# 2603         3.0       1977   0.014073         B         B         2
# 7738        17.0       1986   0.100456         B         B        43
# 1579         1.0       2017   0.041125         B         B        46
# 5058        17.0       1984   0.298205         B         B        16
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# ...

# %%
data_sorted = data.sort_values('Square')
plt.scatter(data_sorted['Square'], data_sorted['Price'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 21 columns):
# Id                10000 non-null int64
# DistrictId        10000 non-null int64
# Rooms             10000 non-null float64
# Square            10000 non-null float64
# LifeSquare        10000 non-null float64
# KitchenSquare     10000 non-null float64
# Floor             10000 non-null int64
# HouseFloor        10000 non-null float64
# HouseYear         10000 non-null float64
# Ecology_1         10000 non-null float64
# Ecology_2         10000 non-null object
# Ecology_3         10000 non-null object
# Social_1          10000 non-null int64
# Social_2          10000 non-null int64
# Social_3          10000 non-null int64
# Healthcare_1      10000 non-null float64
# Helthcare_2       10000 non-null int64
# Shops_1           10000 non-null int64
# Shops_2           10000 non-null object
# Price             10000 non-null float64
# KitchenSquare2    10000 non-null float64
# ...

# %%
plt.scatter(data.loc[data['Rooms'], 'Price'], 
            data.loc[data['Rooms'], 'Price'])

# %%
data.loc[(data["Square"] > 250)]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 1982   5548          86    5.0  275.645284  233.949309           26.0     12
# 4262     28           9    2.0  604.705972         NaN            1.0     17
# 4690   2307         102    1.0  409.425181  410.639749           10.0      4
# 6977  11602          30    2.0  641.065193  638.163193           10.0     20
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1982        37.0       2011   0.161976         B         A        31
# 4262        18.0       1977   0.161532         B         B        25
# 4690         4.0       2016   0.238617         B         B        26
# 6977        19.0       2019   0.000078         B         B        22
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 1982      7010         5        4508.0            3        7       B
# 4262      5648         1          30.0            2        4       B
# ...

# %%
data['Rooms'].value_counts()
# Out:
# 2.0     3880
# 1.0     3705
# 3.0     2235
# 4.0      150
# 5.0       18
# 0.0        8
# 10.0       2
# 19.0       1
# 6.0        1
# Name: Rooms, dtype: int64

# %%
data.loc[(data["Rooms"] >= 6) | (data["Rooms"] == 0)]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 1397  12638          27    0.0  138.427694  136.215499            0.0      4
# 1981   7917          27    0.0  212.932361  211.231125            0.0      2
# 2170  14003          99    6.0   59.414334   38.702244            6.0      7
# 2269   7317          27    0.0   41.790881   35.522249            0.0     13
# 3911    770          28    0.0   49.483501   42.060976            0.0     16
# 4366    456           6    0.0   81.491446   69.267730            0.0      4
# 4853   3224          27    0.0    2.377248    2.020660            0.0      1
# 6149   3159          88    0.0   38.697117   19.345131            9.0      9
# 8834   9443          27    0.0   87.762616   85.125471            0.0      5
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1397         3.0     2016.0   0.075424         B         B        11
# ...

# %%
data.loc[data['Rooms'] == 10, 'Rooms'] = data['Rooms'] - 9

# %%
data_sorted2 = data.sort_values('KitchenSquare')
plt.scatter(data_sorted['KitchenSquare'], data_sorted['Price'])

# %%
data['KitchenSquare'].value_counts()
# Out:
# 1.0      2461
# 8.0      1306
# 5.0      1169
# 10.0     1075
# 6.0      1038
# 9.0       843
# 0.0       697
# 7.0       609
# 12.0      249
# 11.0      233
# 13.0       68
# 14.0       51
# 4.0        39
# 15.0       31
# 3.0        22
# 16.0       16
# 20.0       14
# 17.0       12
# 19.0       11
# 18.0        6
# 2.0         4
# 22.0        3
# 25.0        2
# 112.0       2
# 32.0        2
# 58.0        2
# 43.0        2
# 41.0        2
# 37.0        2
# 51.0        2
# 30.0        2
# 26.0        1
# 27.0        1
# 84.0        1
# 62.0        1
# 42.0        1
# 63.0        1
# 39.0        1
# 72.0        1
# 60.0        1
# 36.0        1
# 48.0        1
# 21.0        1
# 54.0        1
# 96.0        1
# 29.0        1
# 23.0        1
# 73.0        1
# 40.0        1
# 66.0        1
# 35.0        1
# 75.0        1
# 53.0        1
# 31.0        1
# 78.0        1
# 123.0       1
# Name: KitchenSquare, dtype: int64

# %%
data.loc[(data["KitchenSquare"] > 1000)]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price]
# Index: []

# %%
data.loc[data['KitchenSquare'] > 1000, 'KitchenSquare'] = round(data['Square'] - data['LifeSquare'])

# %%
mean_year = np.round(data.loc[data['HouseYear'] <= 2020, 'HouseYear'].mean())
mean_year
# Out:
# 1985.0

# %%
data.loc[data['HouseYear'] > 2020, 'HouseYear'] = mean_year

# %%
data.loc[(data['LifeSquare'] < 5) | (data['LifeSquare'].isnull()), 'LifeSquare'] = data['Square']*0.85

# %%
mean_healthcare = np.round(data.loc[data['Healthcare_1'].notnull(), 'Healthcare_1'].mean())
mean_healthcare
# Out:
# 1143.0

# %%
data.loc[data['Healthcare_1'].isnull(), 'Healthcare_1'] = mean_healthcare

# %% [markdown]
# ## MODEL

# %%
from sklearn.ensemble import RandomForestRegressor as RFR

# %%
model = RFR(max_depth=12, random_state=42)

# %%
feats = ['Square', 'Rooms', 'HouseYear', 'Ecology_1']

# %%
model.fit(train.loc[:, feats], train['Price'])
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=12,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=42, verbose=0, warm_start=False)

# %%
y_pred_train = model.predict(train.loc[:, feats])

# %%
y_pred_train
# Out:
# array([123393.29527865, 206945.93686482, 182217.59722129, ...,
#        238858.82937481, 204397.21963466, 324096.03974631])

# %%
from sklearn.metrics import r2_score as r2

# %%
r2(train['Price'], y_pred_train)
# Out:
# 0.8462476056321439

# %% [markdown]
# ## Загрузка файла

# %%
test = pd.read_csv(r'C:\Users\Public\Kurs_project_task\test.csv')

# %%
test['Price'] = model.predict(test.loc[:, feats])

# %%
test.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0    725          58    2.0  49.882643   33.432782            6.0      6
# 1  15856          74    2.0  69.263183         NaN            1.0      6
# 2   5480         190    1.0  13.597819   15.948246           12.0      2
# 3  15664          47    2.0  73.046609   51.940842            9.0     22
# 4  14275          27    1.0  47.527111   43.387569            1.0     17
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0        14.0       1972   0.310199         B         B        11      2748
# 1         1.0       1977   0.075779         B         B         6      1437
# 2         5.0       1909   0.000000         B         B        30      7538
# 3        22.0       2007   0.101872         B         B        23      4583
# 4        17.0       2017   0.072158         B         B         2       629
#
# ...

# %%
test.loc[:, ['Id', 'Price']].to_csv('AABeletskiy_predictions.csv', index=None)
